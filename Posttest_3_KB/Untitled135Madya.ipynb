# %% [markdown]
# Import Library Pandas, Matplotlib dan Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Menampilkan atribut pada Dataset

# %%
rt.keys()
# Out:
# Index(['Title', 'Genres', 'Rank', 'Popularity', 'Score', 'Episodes',
#        'Episode length', 'Release Date'],
#       dtype='object')

# %% [markdown]
# Menampilkan informasi Dataset

# %%
rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           20343 non-null  object
#  1   Genres          10016 non-null  object
#  2   Rank            20343 non-null  object
#  3   Popularity      20343 non-null  int64
#  4   Score           14019 non-null  float64
#  5   Episodes        20343 non-null  object
#  6   Episode length  20343 non-null  object
#  7   Release Date    5087 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# Mengetahui Deskripsi Dataset

# %%
rt.describe()
# Out:
#          Popularity         Score
# count  20343.000000  14019.000000
# mean   10174.477953      6.451633
# std     5874.844237      0.905774
# min        1.000000      1.840000
# 25%     5086.500000      5.830000
# 50%    10175.000000      6.460000
# 75%    15263.500000      7.110000
# max    20349.000000      9.140000

# %% [markdown]
# Membaca File record MALratingsNumber.csv

# %%
rtp = pd.read_csv('MALratingsNumber.csv')
rtp
# Out:
#        Unnamed: 0  Popularity  Score
# 0               0         404   8.99
# 1               1         533   8.96
# 2               2         939   8.93
# 3               3         735   8.99
# 4               4          19   8.96
# ...           ...         ...    ...
# 20338       20338          13   9.08
# 20339       20339        6095   5.58
# 20340       20340        5064   6.04
# 20341       20341        5329   6.81
# 20342       20342       10052   6.12
#
# [20343 rows x 3 columns]

# %% [markdown]
# Menampilkan nilai data Korelasi

# %%
rtp.corr()
# Out:
#             Unnamed: 0  Popularity     Score
# Unnamed: 0    1.000000   -0.429379  0.377522
# Popularity   -0.429379    1.000000 -0.687303
# Score         0.377522   -0.687303  1.000000

# %% [markdown]
# Menampilkan data Informasi

# %%
rtp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20343 entries, 0 to 20342
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20343 non-null  int64
#  1   Popularity  20343 non-null  int64
#  2   Score       14019 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 476.9 KB

# %% [markdown]
# membuat Grafik Heatmap

# %%
sns.heatmap(data=rtp.corr(), cmap="Blues")
plt.show()

# %% [markdown]
# Membuat Grafik Plot dan Garis

# %%
plt.figure(figsize=(7,3))
plt.plot(rtp.head()['Popularity'], rtp.head()['Score'], label = 'Anime Popularity Score', linestyle='--')
plt.legend()
plt.title('Anime Score Popularity')
plt.xlabel('Popularity',fontsize=12)
plt.ylabel('Score Rank',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Membuat Grafik Scatter Plot

# %%
plt.scatter(rtp.head()['Score'], rtp.head()['Popularity'], label='Anime Score Popularity')
plt.legend()
plt.title('Anime Score Popularity')
plt.xlabel('Score Rank',fontsize=12)
plt.ylabel('Popularity',fontsize=12)
# Out:
# Text(0, 0.5, 'Popularity')

# %% [markdown]
# Membuat Grafik Pie

# %%
rt = pd.read_csv("MALratings.csv")

plt.figure(figsize=(7,3))
plt.pie(rt.head(2)['Rank'].value_counts(), labels=['0 - 5.0','5.1  9.9'], startangle=90, autopct= '%.1f%%', pctdistance=0.5, explode=(0.03,0))
plt.title('Anime Score Rank')
plt.legend(loc='lower right')
plt.show()
